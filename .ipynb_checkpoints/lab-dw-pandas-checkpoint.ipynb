# %% [markdown]
# # Lab | Pandas

# %% [markdown]
# Objective: practice how to use the pandas library in Python for data analysis and manipulation.

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# The data includes information such as customer ID, state, gender, education, income, and other variables that can be used to perform various analyses.
#
# Throughout the lab, we will be using the pandas library in Python to manipulate and analyze the data. Pandas is a powerful library that provides various data manipulation and analysis tools, including the ability to load and manipulate data from a variety of sources, including CSV files.

# %% [markdown]
# ### Data Description
#
# - Customer - Customer ID
#
# - ST - State where customers live
#
# - Gender - Gender of the customer
#
# - Education - Background education of customers
#
# - Customer Lifetime Value - Customer lifetime value(CLV) is the total revenue the client will derive from their entire relationship with a customer. In other words, is the predicted or calculated value of a customer over their entire duration as a policyholder with the insurance company. It is an estimation of the net profit that the insurance company expects to generate from a customer throughout their relationship with the company. Customer Lifetime Value takes into account factors such as the duration of the customer's policy, premium payments, claim history, renewal likelihood, and potential additional services or products the customer may purchase. It helps insurers assess the long-term profitability and value associated with retaining a particular customer.
#
# - Income - Customers income
#
# - Monthly Premium Auto - Amount of money the customer pays on a monthly basis as a premium for their auto insurance coverage. It represents the recurring cost that the insured person must pay to maintain their insurance policy and receive coverage for potential damages, accidents, or other covered events related to their vehicle.
#
# - Number of Open Complaints - Number of complaints the customer opened
#
# - Policy Type - There are three type of policies in car insurance (Corporate Auto, Personal Auto, and Special Auto)
#
# - Vehicle Class - Type of vehicle classes that customers have Two-Door Car, Four-Door Car SUV, Luxury SUV, Sports Car, and Luxury Car
#
# - Total Claim Amount - the sum of all claims made by the customer. It represents the total monetary value of all approved claims for incidents such as accidents, theft, vandalism, or other covered events.

# %% [markdown]
# External Resources: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %% [markdown]
# ## Challenge 1: Understanding the data
#
# In this challenge, you will use pandas to explore a given dataset. Your task is to gain a deep understanding of the data by analyzing its characteristics, dimensions, and statistical properties.

# %% [markdown]
# - Identify the dimensions of the dataset by determining the number of rows and columns it contains.
# - Determine the data types of each column and evaluate whether they are appropriate for the nature of the variable. You should also provide suggestions for fixing any incorrect data types.
# - Identify the number of unique values for each column and determine which columns appear to be categorical. You should also describe the unique values of each categorical column and the range of values for numerical columns, and give your insights.
# - Compute summary statistics such as mean, median, mode, standard deviation, and quartiles to understand the central tendency and distribution of the data for numerical columns. You should also provide your conclusions based on these summary statistics.
# - Compute summary statistics for categorical columns and providing your conclusions based on these statistics.

# %%
import pandas as pd
import numpy as np

insurance = pd.read_csv('./customer.csv')

# %%
# Your code here

# %%
insurance
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Drop duplicates

insurance = insurance[insurance['Customer'].isna()==False]
insurance
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
insurance['Customer Lifetime Value'] = insurance['Customer Lifetime Value'].str.rstrip('%').astype('float') / 100.0

insurance
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\142663419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['Customer Lifetime Value'] = insurance['Customer Lifetime Value'].str.rstrip('%').astype('float') / 100.0
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# ...

# %%
insurance.rename(columns={'ST': 'State', 'GENDER': 'Gender'}, inplace=True)

insurance
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\3315238529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance.rename(columns={'ST': 'State', 'GENDER': 'Gender'}, inplace=True)
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# ...

# %%
#Check unique values for insurance

insurance['State'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA'], dtype=object)

# %%
# Create a function to replace values in a column so that we can call it later

def clean_state(x):
    if x in ['AZ']:
        return 'Arizona'
    elif x in ['WA']:
        return 'Washington'
    elif x in ['Cali']:
        return 'California'
    else:
        return x

# Call the function

insurance['State'] = list(map(clean_state, insurance['State']))

# Check

insurance['State'].unique()
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\1515050858.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['State'] = list(map(clean_state, insurance['State']))
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
#Check unique values for insurance

insurance['Gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
# I´m going to do the same for the rest of categorical columns

insurance['Gender'].unique()

def clean_gender(x):
    if x in ['Femal','female']:
        return 'F'
    elif x in ['Male']:
        return 'M'
    else:
        return 'U'
    
insurance['Gender'] = list(map(clean_gender, insurance['Gender']))

insurance['Gender'].unique()
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\1396499023.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['Gender'] = list(map(clean_gender, insurance['Gender']))
# array(['U', 'F', 'M'], dtype=object)

# %%
#Check unique values for insurance

insurance['Education'].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College',
#        'Bachelors', 'Doctor'], dtype=object)

# %%
# Clean/Updated the Education column

insurance['Education'].unique()

insurance['Education'].replace('Bachelors', 'Bachelor', inplace=True)

insurance['Education'].unique()
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\739478905.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['Education'].replace('Bachelors', 'Bachelor', inplace=True)
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor'],
#       dtype=object)

# %%
insurance
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington      U                Master
# 1     QZ44356     Arizona      U              Bachelor
# 2     AI49188      Nevada      U              Bachelor
# 3     WW63253  California      U              Bachelor
# 4     GA49547  Washington      U  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      U                Master
# 1067  VJ51327  California      U  High School or Below
# 1068  GS98873     Arizona      U              Bachelor
# 1069  CW49887  California      U                Master
# 1070  MY31220  California      U               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
insurance['Number of Open Complaints'].unique()
insurance[insurance['Number of Open Complaints'].isna()==True]

# I guess the middle is the number of complaints

insurance['Number of Open Complaints'].replace('1/0/00', '0', inplace=True)
insurance[insurance['Number of Open Complaints']=='0'].head(60)
insurance['Number of Open Complaints'].replace('1/1/00', '1', inplace=True)
insurance['Number of Open Complaints'].replace('1/2/00', '2', inplace=True)
insurance['Number of Open Complaints'].replace('1/3/00', '3', inplace=True)
insurance['Number of Open Complaints'].replace('1/4/00', '4', inplace=True)
insurance['Number of Open Complaints'].replace('1/5/00', '5', inplace=True)
insurance[insurance['Number of Open Complaints'].isin(['0','1','2','3','4','5'])]

insurance['Number of Open Complaints'] =  pd.to_numeric(insurance['Number of Open Complaints'], errors='coerce') #errors replace non numeric it for NaN


insurance['Number of Open Complaints'] = insurance['Number of Open Complaints'].astype(int)

insurance.dtypes

display(insurance)
# Out:
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\349412315.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['Number of Open Complaints'].replace('1/0/00', '0', inplace=True)
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\349412315.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance['Number of Open Complaints'].replace('1/1/00', '1', inplace=True)
# C:\Users\menno\AppData\Local\Temp\ipykernel_7760\349412315.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
insurance
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington      U                Master
# 1     QZ44356     Arizona      U              Bachelor
# 2     AI49188      Nevada      U              Bachelor
# 3     WW63253  California      U              Bachelor
# 4     GA49547  Washington      U  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      U                Master
# 1067  VJ51327  California      U  High School or Below
# 1068  GS98873     Arizona      U              Bachelor
# 1069  CW49887  California      U                Master
# 1070  MY31220  California      U               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
# Check the number of NaN by column

insurance.isna().sum()
# Out:
# Customer                     0
# State                        0
# Gender                       0
# Education                    0
# Customer Lifetime Value      3
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# dtype: int64

# %%
def round(x):
    return round(x,2)

# %%
# Check the number of NaN by column

insurance.isna().sum()
# Out:
# Customer                     0
# State                        0
# Gender                       0
# Education                    0
# Customer Lifetime Value      3
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# dtype: int64

# %%
df_forward_fill = df.fillna(method='Customer Lifetime Value')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_forward_fill = df.fillna(method='Customer Lifetime Value')
#
# NameError: name 'df' is not defined

# %%
# Now I´m going to check the numeric values
# Quick check
insurance.head(60)

# Quick check
insurance.describe(include='all').T

# Check the number of NaN by column

insurance.isna().sum()

# Change insurance data type
# insurance['Customer Lifetime Value'] = insurance['Customer Lifetime Value'].str.rstrip('%').astype('float') / 100.0
insurance

# Check if Customer Lifetime Value can have 0 as a value
insurance[insurance['Customer Lifetime Value']==0.0000]

# Replace Nan values by the mean

#First calculate the mean:

print('Customer Lifetime Value mean: ', insurance['Customer Lifetime Value'].mean())

# Replace Nan values by the mean

Customer_Lifetime_Value_mean=insurance['Customer Lifetime Value'].mean()

insurance['Customer Lifetime Value'] = insurance['Customer Lifetime Value'].fillna(Customer_Lifetime_Value_mean)

# Check if there is still NaN values
insurance.isna().sum()

# %% [markdown]
# ## Challenge 2: analyzing the data

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The marketing team wants to know the top 5 less common customer locations. Create a pandas Series object that contains the customer locations and their frequencies, and then retrieve the top 5 less common locations in ascending order.

# %%
# Count the frequencies of each customer location
customer_locations_counts = insurance['State'].value_counts()

# Sort the customer locations in ascending order by their frequencies
sorted_customer_locations = customer_locations_counts.sort_values()

# Get the top 5 least common customer locations
top_5_less_common_locations = sorted_customer_locations.head(5)

# Display the result
top_5_less_common_locations

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your goal is to identify customers with a high policy claim amount.
#
# Instructions:
#
# - Review again the statistics for total claim amount to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount data.

# %% [markdown]
# *Note: When analyzing data, we often want to focus on certain groups of values to gain insights. Percentiles are a useful tool to help us define these groups. A percentile is a measure that tells us what percentage of values in a dataset are below a certain value. For example, the 75th percentile represents the value below which 75% of the data falls. Similarly, the 25th percentile represents the value below which 25% of the data falls. When we talk about the top 25%, we are referring to the values that fall above the 75th percentile, which represent the top quarter of the data. On the other hand, when we talk about the bottom 25%, we are referring to the values that fall below the 25th percentile, which represent the bottom quarter of the data. By focusing on these groups, we can identify patterns and trends that may be useful for making decisions and taking action.*
#
# *Hint: look for a method that gives you the percentile or quantile 0.75 and 0.25 for a Pandas Series.*

# %% [markdown]
# *Hint 2: check `Boolean selection according to the values of a single column` in https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9*

# %%
# Your code here

# Step 1: Calculate the 75th percentile of the total claim amount
claim_amount_75th_percentile = insurance['Total Claim Amount'].quantile(0.75)

# Step 2: Filter high policy claim amount customers
high_claim_customers = insurance[insurance['Total Claim Amount'] > claim_amount_75th_percentile]

# Step 3: Information about high policy claim amount customers
high_claim_customers_df = pd.DataFrame(high_claim_customers)

# Step 4: Calculate summary statistics for this data
summary_statistics = high_claim_customers_df.describe()

# Display the result
summary_statistics
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count               264.000000    264.000000            264.000000
# mean               9086.868131  23677.344697            165.193182
# std                6387.677898  27013.483721            623.930992
# min                2287.596900      0.000000             63.000000
# 25%                4723.957925      0.000000             99.000000
# 50%                7781.768250  18807.000000            114.000000
# 75%               10544.299275  42423.750000            133.250000
# max               38445.855900  99316.000000          10202.000000
#
#        Number of Open Complaints  Total Claim Amount
# count                 264.000000          264.000000
# mean                    0.416667          782.228263
# std                     0.943593          292.751640
# min                     0.000000          537.600000
# 25%                     0.000000          606.521741
# ...

# %% [markdown]
# ### Exercise 3
#
# The sales team wants to know the total number of policies sold for each type of policy. Create a pandas Series object that contains the policy types and their total number of policies sold, and then retrieve the policy type with the highest number of policies sold.

# %% [markdown]
# *Hint:*
# - *Using value_counts() method simplifies this analysis.*
# - *Futhermore, there is a method that returns the index of the maximum value in a column or row.*

# %%
# Your code here

# Step 1: Series with policy types and their total number of policies sold
policy_counts = insurance['Policy Type'].value_counts()

# Step 2: Policy type with the highest number of policies sold
policy_with_highest_sales = policy_counts.idxmax()

# The total number of policies sold for each type of policy
print(policy_counts)

# Display the policy type with the highest number of policies sold
print("Policy type with the highest number of policies sold:", policy_with_highest_sales)
# Out:
# Personal Auto     780
# Corporate Auto    234
# Special Auto       57
# Name: Policy Type, dtype: int64
# Policy type with the highest number of policies sold: Personal Auto

# %% [markdown]
# ### Exercise 4
#
# The sales team wants to know if customers with Personal Auto have a income less than those with Corporate Auto. How does the average income compare between the two policy types?

# %% [markdown]
# - Use *loc* to create two dataframes: one containing only Personal Auto policies and one containing only Corporate Auto policies.
# - Calculate the average income for each policy.
# - Print the results.

# %%
# Your code here

# Step 1: Create two dataframes, one for Personal Auto policies and another for Corporate Auto policies
personal_auto_df = insurance.loc[insurance['Policy Type'] == 'Personal Auto']
corporate_auto_df = insurance.loc[insurance['Policy Type'] == 'Corporate Auto']

# Step 2: Calculate the average income for each policy type
average_income_personal_auto = personal_auto_df['Income'].mean()
average_income_corporate_auto = corporate_auto_df['Income'].mean()

# Step 3: Print the results
print("Average income for Personal Auto policies:", average_income_personal_auto)
print("Average income for Corporate Auto policies:", average_income_corporate_auto)
# Out:
# Average income for Personal Auto policies: 38180.69871794872
# Average income for Corporate Auto policies: 41390.31196581197
